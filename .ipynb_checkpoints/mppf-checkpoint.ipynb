# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders
# Out:
# WARNING:tensorflow:From c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# splits dataset it into three subfolders: train, val (validation), and test.

splitfolders.ratio("Medicinal plant dataset", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 5945 files [02:09, 45.98 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 40 folder and 0 images in output\test
# 0 folder and 9 images in output\test\Aloevera
# 0 folder and 8 images in output\test\Amla
# 0 folder and 8 images in output\test\Amruta_Balli
# 0 folder and 8 images in output\test\Arali
# 0 folder and 8 images in output\test\Ashoka
# 0 folder and 8 images in output\test\Ashwagandha
# 0 folder and 8 images in output\test\Avacado
# 0 folder and 8 images in output\test\Bamboo
# 0 folder and 8 images in output\test\Basale
# 0 folder and 8 images in output\test\Betel
# 0 folder and 8 images in output\test\Betel_Nut
# 0 folder and 8 images in output\test\Brahmi
# 0 folder and 8 images in output\test\Castor
# 0 folder and 8 images in output\test\Curry_Leaf
# 0 folder and 8 images in output\test\Doddapatre
# 0 folder and 8 images in output\test\Ekka
# 0 folder and 6 images in output\test\Ganike
# 0 folder and 8 images in output\test\Gauva
# 0 folder and 8 images in output\test\Geranium
# 0 folder and 8 images in output\test\Henna
# 0 folder and 9 images in output\test\Hibiscus
# 0 folder and 8 images in output\test\Honge
# 0 folder and 8 images in output\test\Insulin
# 0 folder and 10 images in output\test\Jasmine
# 0 folder and 8 images in output\test\Lemon
# 0 folder and 8 images in output\test\Lemon_grass
# 0 folder and 8 images in output\test\Mango
# 0 folder and 9 images in output\test\Mint
# 0 folder and 8 images in output\test\Nagadali
# 0 folder and 8 images in output\test\Neem
# 0 folder and 8 images in output\test\Nithyapushpa
# 0 folder and 8 images in output\test\Nooni
# 0 folder and 8 images in output\test\Pappaya
# 0 folder and 8 images in output\test\Pepper
# 0 folder and 8 images in output\test\Pomegranate
# 0 folder and 8 images in output\test\Raktachandini
# 0 folder and 9 images in output\test\Rose
# 0 folder and 8 images in output\test\Sapota
# 0 folder and 8 images in output\test\Tulasi
# 0 folder and 8 images in output\test\Wood_sorel
# 40 folder and 0 images in output\train
# 0 folder and 123 images in output\train\Aloevera
# 0 folder and 109 images in output\train\Amla
# 0 folder and 109 images in output\train\Amruta_Balli
# 0 folder and 109 images in output\train\Arali
# 0 folder and 109 images in output\train\Ashoka
# 0 folder and 109 images in output\train\Ashwagandha
# 0 folder and 109 images in output\train\Avacado
# 0 folder and 109 images in output\train\Bamboo
# 0 folder and 109 images in output\train\Basale
# 0 folder and 113 images in output\train\Betel
# 0 folder and 109 images in output\train\Betel_Nut
# 0 folder and 109 images in output\train\Brahmi
# 0 folder and 120 images in output\train\Castor
# 0 folder and 109 images in output\train\Curry_Leaf
# 0 folder and 109 images in output\train\Doddapatre
# 0 folder and 109 images in output\train\Ekka
# 0 folder and 86 images in output\train\Ganike
# 0 folder and 109 images in output\train\Gauva
# 0 folder and 109 images in output\train\Geranium
# 0 folder and 112 images in output\train\Henna
# 0 folder and 123 images in output\train\Hibiscus
# 0 folder and 109 images in output\train\Honge
# 0 folder and 109 images in output\train\Insulin
# 0 folder and 140 images in output\train\Jasmine
# 0 folder and 109 images in output\train\Lemon
# 0 folder and 109 images in output\train\Lemon_grass
# 0 folder and 109 images in output\train\Mango
# 0 folder and 114 images in output\train\Mint
# 0 folder and 114 images in output\train\Nagadali
# 0 folder and 109 images in output\train\Neem
# 0 folder and 109 images in output\train\Nithyapushpa
# 0 folder and 109 images in output\train\Nooni
# 0 folder and 109 images in output\train\Pappaya
# 0 folder and 109 images in output\train\Pepper
# 0 folder and 109 images in output\train\Pomegranate
# 0 folder and 109 images in output\train\Raktachandini
# 0 folder and 126 images in output\train\Rose
# 0 folder and 109 images in output\train\Sapota
# 0 folder and 109 images in output\train\Tulasi
# 0 folder and 109 images in output\train\Wood_sorel
# 40 folder and 0 images in output\val
# 0 folder and 32 images in output\val\Aloevera
# 0 folder and 29 images in output\val\Amla
# 0 folder and 29 images in output\val\Amruta_Balli
# 0 folder and 29 images in output\val\Arali
# 0 folder and 29 images in output\val\Ashoka
# 0 folder and 29 images in output\val\Ashwagandha
# 0 folder and 29 images in output\val\Avacado
# 0 folder and 29 images in output\val\Bamboo
# 0 folder and 29 images in output\val\Basale
# 0 folder and 30 images in output\val\Betel
# 0 folder and 29 images in output\val\Betel_Nut
# 0 folder and 29 images in output\val\Brahmi
# 0 folder and 32 images in output\val\Castor
# 0 folder and 29 images in output\val\Curry_Leaf
# 0 folder and 29 images in output\val\Doddapatre
# 0 folder and 29 images in output\val\Ekka
# 0 folder and 23 images in output\val\Ganike
# 0 folder and 29 images in output\val\Gauva
# 0 folder and 29 images in output\val\Geranium
# 0 folder and 30 images in output\val\Henna
# 0 folder and 33 images in output\val\Hibiscus
# 0 folder and 29 images in output\val\Honge
# 0 folder and 29 images in output\val\Insulin
# 0 folder and 37 images in output\val\Jasmine
# 0 folder and 29 images in output\val\Lemon
# 0 folder and 29 images in output\val\Lemon_grass
# 0 folder and 29 images in output\val\Mango
# 0 folder and 30 images in output\val\Mint
# 0 folder and 30 images in output\val\Nagadali
# 0 folder and 29 images in output\val\Neem
# 0 folder and 29 images in output\val\Nithyapushpa
# 0 folder and 29 images in output\val\Nooni
# 0 folder and 29 images in output\val\Pappaya
# 0 folder and 29 images in output\val\Pepper
# 0 folder and 29 images in output\val\Pomegranate
# 0 folder and 29 images in output\val\Raktachandini
# 0 folder and 33 images in output\val\Rose
# 0 folder and 29 images in output\val\Sapota
# 0 folder and 29 images in output\val\Tulasi
# 0 folder and 29 images in output\val\Wood_sorel

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Aloevera')
# Out:
# Image Shape : (450, 600, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 4441 images belonging to 40 classes.
# Found 1180 images belonging to 40 classes.
# Found 324 images belonging to 40 classes.

# %%
train_data.class_indices
# Out:
# {'Aloevera': 0,
#  'Amla': 1,
#  'Amruta_Balli': 2,
#  'Arali': 3,
#  'Ashoka': 4,
#  'Ashwagandha': 5,
#  'Avacado': 6,
#  'Bamboo': 7,
#  'Basale': 8,
#  'Betel': 9,
#  'Betel_Nut': 10,
#  'Brahmi': 11,
#  'Castor': 12,
#  'Curry_Leaf': 13,
#  'Doddapatre': 14,
#  'Ekka': 15,
#  'Ganike': 16,
#  'Gauva': 17,
#  'Geranium': 18,
#  'Henna': 19,
#  'Hibiscus': 20,
#  'Honge': 21,
#  'Insulin': 22,
#  'Jasmine': 23,
#  'Lemon': 24,
#  'Lemon_grass': 25,
#  'Mango': 26,
#  'Mint': 27,
#  'Nagadali': 28,
#  'Neem': 29,
#  'Nithyapushpa': 30,
#  'Nooni': 31,
#  'Pappaya': 32,
#  'Pepper': 33,
#  'Pomegranate': 34,
#  'Raktachandini': 35,
#  'Rose': 36,
#  'Sapota': 37,
#  'Tulasi': 38,
#  'Wood_sorel': 39}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (4441,)
# val_y.shape:  (1180,)
# test_y.shape:  (324,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(40)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 40)             │        41,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 40)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,078,504 (27.00 MB)
#  Trainable params: 41,000 (160.16 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 35/70 ━━━━━━━━━━━━━━━━━━━━ 4:07 7s/step - accuracy: 0.0561 - loss: 3.7865
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       1 model.compile(loss='categorical_crossentropy',
#       2               optimizer=Adam(learning_rate=0.001),
#       3               metrics=['accuracy'])
#       5 # train model
# ----> 6 history = model.fit(train_data, epochs=20, validation_data=valid_data)
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for begin_step, end_step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(begin_step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(end_step, logs)
#     379     if self.stop_training:
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.81        32
#            1       0.23      1.00      0.38         3
#
#     accuracy                           0.71        35
#    macro avg       0.62      0.84      0.59        35
# weighted avg       0.93      0.71      0.78        35

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         9
#            1       0.25      1.00      0.40         1
#
#     accuracy                           0.70        10
#    macro avg       0.62      0.83      0.60        10
# weighted avg       0.93      0.70      0.76        10

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')
